# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,KFold
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_digits

# %%
data=load_digits()

# %%
dir(data)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
Tx,tx,Ty,ty=train_test_split(data.data,data.target,test_size=0.3)

# %%
lr=LogisticRegression()
lr.fit(Tx,Ty)
lr.score(tx,ty)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9666666666666667

# %%
svm=SVC()
svm.fit(Tx,Ty)
svm.score(tx,ty)
# Out:
# 0.9888888888888889

# %%
rf=RandomForestClassifier()
rf.fit(Tx,Ty)
rf.score(tx,ty)
# Out:
# 0.9722222222222222

# %%
def get_score(model,trainx,testx,trainy,testy):
  model.fit(trainx,trainy)
  return model.score(testx,testy)

# %%
k=KFold(n_splits=3)

# %%
lr_score=[]
svm_score=[]
rf_score=[]

# %%
for t,T in k.split(data.data):
  tx,Tx,ty,Ty=data.data[t],data.data[T],data.target[t],data.target[T]
  lr_score.append(get_score(LogisticRegression(),tx,Tx,ty,Ty))
  svm_score.append(get_score(SVC(),tx,Tx,ty,Ty))
  rf_score.append(get_score(RandomForestClassifier(),tx,Tx,ty,Ty))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
np.mean(lr_score)
# Out:
# np.float64(0.9265442404006677)

# %%
np.mean(svm_score)
# Out:
# np.float64(0.9677239844184752)

# %%
np.mean(rf_score)
# Out:
# np.float64(0.9437952142459656)

# %%
from sklearn.model_selection import cross_val_score

# %%
svm_score
# Out:
# [0.9666110183639399, 0.9816360601001669, 0.9549248747913188]

# %%
np.mean(cross_val_score(LogisticRegression(),data.data,data.target))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
