# %% [markdown]
# # ***IMPORTS***

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # ***Data***

# %%
data=pd.read_csv('Housing.csv')
data=pd.DataFrame(data).dropna()

# %%
for i in ['mainroad',	'guestroom'	,'basement'	,'hotwaterheating',	'airconditioning','furnishingstatus','prefarea']:
  data[i]=data[i].str.strip().str.lower()

data['mainroad']=data['mainroad'].map({'yes':1,'no':0})
data['guestroom']=data['guestroom'].map({'yes':1,'no':0})
data['basement']=data['basement'].map({'yes':1,'no':0})
data['hotwaterheating']=data['hotwaterheating'].map({'yes':1,'no':0})
data['airconditioning']=data['airconditioning'].map({'yes':1,'no':0})
data['furnishingstatus']=data['furnishingstatus'].map({'furnished':1,'semi-furnished':0.5,'unfurnished':0})
data['prefarea']=data['prefarea'].map({'yes':1,'no':0})
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
y=data['price']
features=['area','bedrooms','bathrooms','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','furnishingstatus']
x=data[features]
trainx,testx,trainy,testy=train_test_split(x,y,random_state=0)

# %% [markdown]
# # ***DECISION TREE REGRESSOR***

# %%
model=DecisionTreeRegressor(random_state=1)
model.fit(trainx,trainy)

p=model.predict(testx)
mae=mean_absolute_error(testy,p)
mae
# Out:
# 1157197.0802919709

# %% [markdown]
# # MAE Comparison

# %%
print((mae/y.median())*100)
# Out:
# 26.66352719566753

# %% [markdown]
# # ***RANDOM FOREST REGRESSOR***

# %%
new_model=RandomForestRegressor(random_state=1)
new_model.fit(trainx,trainy)

pp=new_model.predict(testx)
mae=mean_absolute_error(testy,pp)
mae
# Out:
# 916561.8411192215

# %% [markdown]
# # MAE Comparison

# %%
print((mae/y.median())*100)
# Out:
# 21.11893643131847

# %% [markdown]
# # ***Exercise***

# %%
data=pd.DataFrame(pd.read_csv('StudentsPerformance.csv')).dropna()
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
for i in ['test preparation course','gender']:
  data[i]=data[i].astype(str).str.strip().str.lower()

data['test preparation course']=data['test preparation course'].map({'none':False,'completed':True})
# data['gender']=data['gender'].map({'male':True,'female':False})
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
Y=data['gender']
features=['test preparation course','math score','reading score','writing score']
X=data[features]

# %%
train_X,test_X,train_Y,test_Y=train_test_split(X,Y,random_state=0)

# %%
model1=DecisionTreeClassifier(random_state=1)
model1.fit(train_X,train_Y)
# m1=DecisionTreeRegressor(random_state=1)
# m1.fit(train_X,train_Y)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
p1=model1.predict(test_X)
accuracy_score(test_Y,p1)
# P1=m1.predict(test_X)
# accuracy_score(test_Y,P1)
p1
# Out:
# array(['female', 'male', 'female', 'male', 'female', 'male', 'female',
#        'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female',
#        'female', 'male', 'female', 'female', 'male', 'male', 'female',
#        'female', 'male', 'male', 'male', 'male', 'male', 'female',
#        'female', 'female', 'male', 'female', 'female', 'male', 'male',
#        'female', 'male', 'female', 'female', 'male', 'male', 'male',
#        'female', 'female', 'female', 'female', 'female', 'female',
#        'female', 'male', 'male', 'male', 'male', 'male', 'female',
#        'female', 'male', 'male', 'female', 'female', 'female', 'male',
#        'male', 'male', 'female', 'male', 'female', 'female', 'male',
#        'male', 'male', 'male', 'female', 'male', 'male', 'female',
#        'female', 'male', 'female', 'male', 'female', 'female', 'female',
#        'female', 'male', 'female', 'female', 'female', 'female', 'female',
# ...

# %%
model2=RandomForestClassifier(random_state=1)
model2.fit(train_X,train_Y)
# m2=RandomForestRegressor(random_state=1)
# m2.fit(train_X,train_Y)
# Out:
# RandomForestClassifier(random_state=1)

# %%
p2=model2.predict(test_X)
accuracy_score(test_Y,p2)
# P2=m2.predict(test_X)
# P2
p2
# Out:
# array(['female', 'male', 'male', 'male', 'female', 'male', 'female',
#        'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female',
#        'female', 'male', 'female', 'female', 'male', 'male', 'female',
#        'female', 'male', 'male', 'male', 'male', 'male', 'female',
#        'female', 'female', 'male', 'female', 'female', 'male', 'male',
#        'female', 'male', 'female', 'female', 'male', 'male', 'male',
#        'female', 'female', 'female', 'female', 'female', 'female',
#        'female', 'male', 'male', 'female', 'male', 'male', 'female',
#        'female', 'male', 'male', 'female', 'female', 'female', 'female',
#        'male', 'male', 'female', 'male', 'female', 'female', 'male',
#        'male', 'male', 'male', 'female', 'male', 'male', 'female',
#        'female', 'male', 'female', 'male', 'female', 'female', 'female',
#        'female', 'male', 'female', 'female', 'female', 'female', 'female',
# ...

# %% [markdown]
# # ***MAE COMPARISON***

# %%
print('DecisionTreeMAE % =',(mae1/Y.median())*100)
print('RandomForestMAE % =',(mae2/Y.median())*100)
# Out:
# DecisionTreeMAE % = gender             inf
# math score    7.803283
# dtype: float64
# RandomForestMAE % = gender             inf
# math score    6.635237
# dtype: float64

# %% [markdown]
# # ***MY CUSTOM TEST***

# %%
m={'test preparation course':[True,False],'math score':[95,98],'reading score':[96,89],'writing score':[90,95]}
df=pd.DataFrame(m)
df
# Out:
#    test preparation course  math score  reading score  writing score
# 0                     True          95             96             90
# 1                    False          98             89             95

# %%
a=model1.predict(df)
a
# Out:
# array(['male', 'female'], dtype=object)

# %%
a=model2.predict(df)
# b=[]
# for j in a:
#   if j[0].round()==0:
#     b.append('Female')
#     b.append(float(j[1]))
#   else:
#     b.append('Male')
#     b.append(float(round(j[1])))
# print(b)
a
# Out:
# array(['male', 'female'], dtype=object)
