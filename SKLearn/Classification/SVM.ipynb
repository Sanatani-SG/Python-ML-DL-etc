# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
data=pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
data['Target']=iris.target

# %%
data['Flower']=data.Target.apply(lambda x:iris.target_names[x])

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  ...  Target     Flower
# 0                  5.1               3.5  ...       0     setosa
# 1                  4.9               3.0  ...       0     setosa
# 2                  4.7               3.2  ...       0     setosa
# 3                  4.6               3.1  ...       0     setosa
# 4                  5.0               3.6  ...       0     setosa
# ..                 ...               ...  ...     ...        ...
# 145                6.7               3.0  ...       2  virginica
# 146                6.3               2.5  ...       2  virginica
# 147                6.5               3.0  ...       2  virginica
# 148                6.2               3.4  ...       2  virginica
# 149                5.9               3.0  ...       2  virginica
#
# [150 rows x 6 columns]

# %%
d1=data[data.Target==1]
d0=data[data.Target==0]
d2=data[data.Target==2]

# %%
d1
# Out:
#     sepal length (cm)  sepal width (cm)  ...  Target      Flower
# 50                7.0               3.2  ...       1  versicolor
# 51                6.4               3.2  ...       1  versicolor
# 52                6.9               3.1  ...       1  versicolor
# 53                5.5               2.3  ...       1  versicolor
# 54                6.5               2.8  ...       1  versicolor
# 55                5.7               2.8  ...       1  versicolor
# 56                6.3               3.3  ...       1  versicolor
# 57                4.9               2.4  ...       1  versicolor
# 58                6.6               2.9  ...       1  versicolor
# 59                5.2               2.7  ...       1  versicolor
# 60                5.0               2.0  ...       1  versicolor
# 61                5.9               3.0  ...       1  versicolor
# 62                6.0               2.2  ...       1  versicolor
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(d1['sepal length (cm)'],d1['sepal width (cm)'],c='red')
# plt.scatter(d2['sepal length (cm)'],d2['sepal width (cm)'],c='blue',marker='*')
plt.scatter(d0['sepal length (cm)'],d0['sepal width (cm)'],c='orange',marker='+')

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.drop(['Target',	'Flower'],axis=1)
y=data['Target']

# %%
tx,Tx,ty,Ty=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC

# %%
model=SVC()
model.fit(tx,ty)
# Out:
# SVC()

# %%
model.score(Tx,Ty)
# Out:
# 0.9666666666666667

# %% [markdown]
# ***We can also use SVR for regression***

# %%
from sklearn.svm import SVR
